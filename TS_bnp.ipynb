# %%
import pandas as pd
import numpy as np
import math
from datetime import datetime
import matplotlib.pyplot as plt # Visualization
import matplotlib.dates as mdates # Formatting dates
import seaborn as sns # Visualization
from sklearn.preprocessing import MinMaxScaler
import torch # Library for implementing Deep Neural Network
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
df = pd.read_csv('BNP.PA.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df = df.dropna()

# %%
def data_plot(df):
	df_plot = df.copy()

	ncols = 2
	nrows = int(round(df_plot.shape[1] / ncols, 0))

	fig, ax = plt.subplots(nrows=nrows, ncols=ncols,
						sharex=True, figsize=(14, 7))
	for i, ax in enumerate(fig.axes):
		sns.lineplot(data=df_plot.iloc[:, i], ax=ax)
		ax.tick_params(axis="x", rotation=30, labelsize=10, length=0)
		ax.xaxis.set_major_locator(mdates.AutoDateLocator())
	fig.tight_layout()
	plt.show()

data_plot(df)

# %%
# Train-Test Split
# Setting 80 percent data for training
training_data_len = math.ceil(len(df) * .8)
training_data_len

#Splitting the dataset
train_data = df[:training_data_len].iloc[:,:1]
test_data = df[training_data_len:].iloc[:,:1]
print(train_data.shape, test_data.shape)
# Out:
# (6234, 1) (1558, 1)

# %%
# Selecting Open Price values
dataset_train = train_data.Open.values
# Reshaping 1D to 2D array
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (6234, 1)

# %%
# Selecting Open Price values
dataset_test = test_data.Open.values
# Reshaping 1D to 2D array
dataset_test = np.reshape(dataset_test, (-1,1))
dataset_test.shape
# Out:
# (1558, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
# scaling dataset
scaled_train = scaler.fit_transform(dataset_train)

print(scaled_train[:5])
# Normalizing values between 0 and 1
scaled_test = scaler.fit_transform(dataset_test)
print(*scaled_test[:5]) #prints the first 5 rows of scaled_test
# Out:
# [[0.10377714]
#  [0.10013583]
#  [0.0971014 ]
#  [0.09831517]
#  [0.10377714]]
# [0.8690258] [0.86810666] [0.8598346] [0.86879597] [0.90165443]

# %%
# Create sequences and labels for training data
sequence_length = 50 # Number of time steps to look back
X_train, y_train = [], []
for i in range(len(scaled_train) - sequence_length):
	X_train.append(scaled_train[i:i+sequence_length])
	y_train.append(scaled_train[i+1:i+sequence_length+1])
X_train, y_train = np.array(X_train), np.array(y_train)

# Convert data to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_train.shape,y_train.shape
# Out:
# (torch.Size([6184, 50, 1]), torch.Size([6184, 50, 1]))

# %%
# Create sequences and labels for testing data
sequence_length = 30 # Number of time steps to look back
X_test, y_test = [], []
for i in range(len(scaled_test) - sequence_length):
	X_test.append(scaled_test[i:i+sequence_length])
	y_test.append(scaled_test[i+1:i+sequence_length+1])
X_test, y_test = np.array(X_test), np.array(y_test)

# Convert data to PyTorch tensors
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)
X_test.shape, y_test.shape
# Out:
# (torch.Size([1528, 30, 1]), torch.Size([1528, 30, 1]))

# %%
class LSTMModel(nn.Module):
	# input_size : number of features in input at each time step
	# hidden_size : Number of LSTM units
	# num_layers : number of LSTM layers
	def __init__(self, input_size, hidden_size, num_layers):
		super(LSTMModel, self).__init__() #initializes the parent class nn.Module
		self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
		self.linear = nn.Linear(hidden_size, 1)

	def forward(self, x): # defines forward pass of the neural network
		out, _ = self.lstm(x)
		out = self.linear(out)
		return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
input_size = 1
num_layers = 2
hidden_size = 64
output_size = 1

# Define the model, loss function, and optimizer
model = LSTMModel(input_size, hidden_size, num_layers).to(device)

loss_fn = torch.nn.MSELoss(reduction='mean')

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
print(model)
# Out:
# LSTMModel(
#   (lstm): LSTM(1, 64, num_layers=2, batch_first=True)
#   (linear): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
batch_size = 16
# Create DataLoader for batch training
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Create DataLoader for batch training
test_dataset = torch.utils.data.TensorDataset(X_test, y_test)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
num_epochs = 50
train_hist =[]
test_hist =[]
# Training loop
for epoch in range(num_epochs):
    start_time = datetime.now()
    total_loss = 0.0

    # Training
    model.train()
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        predictions = model(batch_X)
        loss = loss_fn(predictions, batch_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    # Calculate average training loss and accuracy
    average_loss = total_loss / len(train_loader)
    train_hist.append(average_loss)

    # Validation on test data
    model.eval()
    with torch.no_grad():
        total_test_loss = 0.0

        for batch_X_test, batch_y_test in test_loader:
            batch_X_test, batch_y_test = batch_X_test.to(device), batch_y_test.to(device)
            predictions_test = model(batch_X_test)
            test_loss = loss_fn(predictions_test, batch_y_test)

            total_test_loss += test_loss.item()

        # Calculate average test loss and accuracy
        average_test_loss = total_test_loss / len(test_loader)
        test_hist.append(average_test_loss)

    end_time = datetime.now()
    exec_time = duration=(end_time - start_time)
    print(f'Epoch [{epoch+1}/{num_epochs}] - Training Loss: {average_loss:.4f}, Test Loss: {average_test_loss:.4f}, Duration = {exec_time}')
# Out:
# Epoch [1/50] - Training Loss: 0.0143, Test Loss: 0.0071, Duration = 0:00:01.036007
# Epoch [2/50] - Training Loss: 0.0013, Test Loss: 0.0018, Duration = 0:00:01.226158
# Epoch [3/50] - Training Loss: 0.0004, Test Loss: 0.0008, Duration = 0:00:00.970476
# Epoch [4/50] - Training Loss: 0.0002, Test Loss: 0.0006, Duration = 0:00:00.912460
# Epoch [5/50] - Training Loss: 0.0002, Test Loss: 0.0006, Duration = 0:00:00.907391
# Epoch [6/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.947357
# Epoch [7/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.926939
# Epoch [8/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.909156
# Epoch [9/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.904954
# Epoch [10/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.908996
# Epoch [11/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.922521
# Epoch [12/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.933345
# Epoch [13/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.934669
# Epoch [14/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:01.239762
# Epoch [15/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:01.099547
# Epoch [16/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.933008
# Epoch [17/50] - Training Loss: 0.0002, Test Loss: 0.0006, Duration = 0:00:00.915676
# Epoch [18/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.927869
# Epoch [19/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.921816
# Epoch [20/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.926296
# Epoch [21/50] - Training Loss: 0.0002, Test Loss: 0.0006, Duration = 0:00:00.930571
# Epoch [22/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.938227
# Epoch [23/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.933805
# Epoch [24/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.924557
# Epoch [25/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.918796
# Epoch [26/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:01.165641
# Epoch [27/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:01.150974
# Epoch [28/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.934244
# Epoch [29/50] - Training Loss: 0.0002, Test Loss: 0.0006, Duration = 0:00:00.920152
# Epoch [30/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.941192
# Epoch [31/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.928461
# Epoch [32/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.898898
# Epoch [33/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.924477
# Epoch [34/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.918435
# Epoch [35/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.930993
# Epoch [36/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.923325
# Epoch [37/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.925138
# Epoch [38/50] - Training Loss: 0.0002, Test Loss: 0.0006, Duration = 0:00:01.046795
# Epoch [39/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:01.235322
# Epoch [40/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.916615
# Epoch [41/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.907447
# Epoch [42/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.905051
# Epoch [43/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.925358
# Epoch [44/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.910121
# Epoch [45/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.903940
# Epoch [46/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.915554
# Epoch [47/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.895679
# Epoch [48/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.908451
# Epoch [49/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.927117
# Epoch [50/50] - Training Loss: 0.0002, Test Loss: 0.0005, Duration = 0:00:00.967055

# %%
x = np.linspace(1,num_epochs,num_epochs)
plt.plot(x,train_hist,scalex=True, label="Training loss")
plt.plot(x, test_hist, label="Test loss")
plt.legend()
plt.show()

# %%
# Define the number of future time steps to forecast
num_forecast_steps = 30

# Convert to NumPy and remove singleton dimensions
sequence_to_plot = X_test.squeeze().cpu().numpy()

# Use the last 30 data points as the starting point
historical_data = sequence_to_plot[-1]
print(historical_data.shape)

# Initialize a list to store the forecasted values
forecasted_values = []

# Use the trained model to forecast future values
with torch.no_grad():
	for _ in range(num_forecast_steps*2):
		# Prepare the historical_data tensor
		historical_data_tensor = torch.as_tensor(historical_data).view(1, -1, 1).float().to(device)
		# Use the model to predict the next value
		predicted_value = model(historical_data_tensor).cpu().numpy()[0, 0]

		# Append the predicted value to the forecasted_values list
		forecasted_values.append(predicted_value[0])

		# Update the historical_data sequence by removing the oldest value and adding the predicted value
		historical_data = np.roll(historical_data, shift=-1)
		historical_data[-1] = predicted_value


# Generate futute dates
last_date = test_data.index[-1]

# Generate the next 30 dates
future_dates = pd.date_range(start=last_date + pd.DateOffset(1), periods=30)

# Concatenate the original index with the future dates
combined_index = test_data.index.append(future_dates)
# Out:
# (30,)

# %%
#set the size of the plot
plt.rcParams['figure.figsize'] = [14, 4]


#Test data
plt.plot(test_data.index[-100:-30], test_data.Open[-100:-30], label = "test_data", color = "b")
#reverse the scaling transformation
original_cases = scaler.inverse_transform(np.expand_dims(sequence_to_plot[-1], axis=0)).flatten()

#the historical data used as input for forecasting
plt.plot(test_data.index[-30:], original_cases, label='actual values', color='green')

#Forecasted Values
#reverse the scaling transformation
forecasted_cases = scaler.inverse_transform(np.expand_dims(forecasted_values, axis=0)).flatten()
# plotting the forecasted values
plt.plot(combined_index[-60:], forecasted_cases, label='forecasted values', color='red')

plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.title('Time Series Forecasting')
plt.grid(True)
